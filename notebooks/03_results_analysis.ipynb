# %%
import pickle

with open('best_action.pkl', 'rb') as file:
    best_action = pickle.load(file)

# %%
with open('optimal_score_v.pkl', 'rb') as file:
    optimal_score_v = pickle.load(file)

# %%
print(best_action["0" * 5 * 5, 1], optimal_score_v["0" * 5 * 5, 1])
